# %%
import matplotlib.pyplot as plt
import h5py
import torch
import numpy as np

# %%
with h5py.File("/home/philipp/Data/edin_dataset/dataset_512.h5", 'r') as hf:
    dset_x_train = np.array(hf['x_ortho'])
    dset_y_train = np.array(hf['x_dsm'])
    dset_x_test = np.array(hf['x_dtm'])
    dset_y_test = np.array(hf['x_slope'])
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-2-46baae0aa1fe> in <module>
# ----> 1 with h5py.File("/home/philipp/Data/edin_dataset/dataset_512.h5", 'r') as hf:
#       2     dset_x_train = np.array(hf['x_ortho'])
#       3     dset_y_train = np.array(hf['x_dsm'])
#       4     dset_x_test = np.array(hf['x_dtm'])
#       5     dset_y_test = np.array(hf['x_slope'])
#
# ~/miniconda3/envs/pytorch/lib/python3.8/site-packages/h5py/_hl/files.py in __init__(self, name, mode, driver, libver, userblock_size, swmr, rdcc_nslots, rdcc_nbytes, rdcc_w0, track_order, **kwds)
#     404             with phil:
#     405                 fapl = make_fapl(driver, libver, rdcc_nslots, rdcc_nbytes, rdcc_w0, **kwds)
# --> 406                 fid = make_fid(name, mode, userblock_size,
#     407                                fapl, fcpl=make_fcpl(track_order=track_order),
# ...

# %% [markdown]
# ## Orthophoto

# %%
dset_x_train.shape
# Out:
# (100, 512, 512, 4)

# %%
mean = 94.71759 
std = 48.496964

# %%
img = np.round(dset_x_train[0] * std + mean).astype(np.uint8)

# %%
plt.imshow(img[:,:,1], cmap="gray")

# %%
plt.imshow(img[:,:,:3])

# %%
plt.imshow(np.roll(img, 1, axis=2)[:,:,:3])

# %%
img
# Out:
# array([[[ 40,  43,  41,  62],
#         [ 41,  45,  44,  62],
#         [ 40,  44,  43,  57],
#         ...,
#         [ 38,  40,  39,  67],
#         [ 43,  45,  45,  82],
#         [ 43,  45,  45,  86]],
#
#        [[ 39,  42,  40,  57],
#         [ 38,  42,  40,  54],
#         [ 39,  43,  41,  53],
#         ...,
#         [ 41,  45,  45,  71],
#         [ 43,  45,  45,  76],
#         [ 42,  44,  44,  77]],
#
#        [[ 39,  43,  41,  57],
#         [ 38,  43,  41,  54],
#         [ 38,  42,  40,  51],
#         ...,
#         [ 42,  44,  45,  67],
#         [ 41,  43,  43,  66],
#         [ 43,  45,  45,  74]],
#
#        ...,
#
#        [[ 45,  46,  43,  69],
#         [ 44,  46,  43,  68],
#         [ 48,  50,  48,  74],
#         ...,
#         [ 46,  47,  42, 126],
#         [ 51,  52,  45, 136],
#         [ 47,  48,  41, 131]],
#
#        [[ 45,  47,  45,  70],
#         [ 46,  48,  46,  70],
#         [ 46,  47,  45,  68],
#         ...,
#         [ 54,  55,  49, 146],
# ...

# %% [markdown]
# ## DSM

# %%
dset_y_train.shape
# Out:
# (100, 512, 512, 1)

# %%
mean_dsm = 4.648031 
std_dsm = 12.43344

# %%
img_dsm = dset_y_train[0] * 12.43344 + 4.648031

# %%
img_dsm[-10:,-10:]
# Out:
# array([[[16.60022  ],
#         [15.833374 ],
#         [15.833374 ],
#         [15.833374 ],
#         [15.833374 ],
#         [15.833374 ],
#         [15.3602295],
#         [15.3602295],
#         [15.3602295],
#         [15.3602295]],
#
#        [[16.60022  ],
#         [15.833374 ],
#         [15.833374 ],
#         [15.833374 ],
#         [15.833374 ],
#         [15.833374 ],
#         [15.3602295],
#         [15.3602295],
#         [15.3602295],
#         [15.3602295]],
#
#        [[16.320557 ],
#         [15.734253 ],
#         [15.734253 ],
#         [15.734253 ],
#         [15.734253 ],
#         [15.734253 ],
#         [17.442505 ],
#         [17.442505 ],
#         [17.442505 ],
#         [17.442505 ]],
#
#        [[16.320557 ],
#         [15.734253 ],
#         [15.734253 ],
#         [15.734253 ],
#         [15.734253 ],
#         [15.734253 ],
#         [17.442505 ],
#         [17.442505 ],
#         [17.442505 ],
#         [17.442505 ]],
#
#        [[16.320557 ],
# ...

# %%
plt.imshow(img_dsm, cmap="gray")

# %%
plt.imshow(dset_x_test[0] * 139.37895 + 1346.2009, cmap="gray")

# %%
plt.imshow(dset_y_test[0] * 9.733992 + 27.917845, cmap="gray")
