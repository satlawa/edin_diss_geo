# %%
import os
import sys
import geopandas
import pandas as pd
try:
    from osgeo import ogr, osr, gdal
except:
    sys.exit('ERROR: cannot find GDAL/OGR modules')

# %%
grid = geopandas.read_file('/home/philipp/Data/edin_diss/GIS_meta/overlap_grid/overlap_01_nordburgenland_wien_grid.shp')

# %%
i = 0
grid.head()
# Out:
#     id           left           top          right        bottom  \
# 0  1.0  596339.288073  492379.06545  598387.288073  490331.06545
# 1  2.0  596339.288073  490331.06545  598387.288073  488283.06545
# 2  3.0  596339.288073  488283.06545  598387.288073  486235.06545
# 3  4.0  596339.288073  486235.06545  598387.288073  484187.06545
# 4  5.0  596339.288073  484187.06545  598387.288073  482139.06545
#
#                                             geometry
# 0  POLYGON ((596339.288 492379.065, 598387.288 49...
# 1  POLYGON ((596339.288 490331.065, 598387.288 49...
# 2  POLYGON ((596339.288 488283.065, 598387.288 48...
# 3  POLYGON ((596339.288 486235.065, 598387.288 48...
# 4  POLYGON ((596339.288 484187.065, 598387.288 48...

# %%
extend = grid.loc[i,'geometry'].bounds

# %%
extend
# Out:
# (596339.2880734366, 490331.0654496529, 598387.2880734366, 492379.0654496529)

# %%
extend[0]
# Out:
# 596339.2880734366

# %%
os.path.isfile('/media/philipp/Elements/2019/2019150_nordburgenland_lb_rgbi.img')
# Out:
# True

# %%
path_raster = '/media/philipp/Elements/2019/2019150_nordburgenland_lb_rgbi.img'
path_out = "/media/philipp/DATA/color_corr_matrix/01_nordburgenland_wien/overlap_{}.tif".format(i)

bashCommand = "gdal_translate -projwin {} {} {} {} -a_nodata 0.0 -of GTiff {} {}".format(extend[0], extend[3], extend[2], extend[1], path_raster, path_out)

# %%
bashCommand
# Out:
# 'gdal_translate -projwin 596339.2880734366 462082.3724556746 598387.2880734366 460034.3724556746 -a_nodata 0.0 -of GTiff /media/philipp/Elements/2019/2019150_nordburgenland_lb_rgbi.img /media/philipp/DATA/color_corr_matrix/02_nordburgenland_mariazell/overlap_0.tif'

# %%
os.system(bashCommand)
# Out:
# 0

# %%
os.path.isfile(path_raster)
# Out:
# True

# %%
for i in range(grid.shape[0]):
    extend = grid.loc[i,'geometry'].bounds
    
    path_raster = '/media/philipp/Elements/2019/2019150_nordburgenland_lb_rgbi.img'
    path_out = "/media/philipp/DATA/color_corr_matrix/01_nordburgenland_wien/overlap_{}.tif".format(i)

    bashCommand = "gdal_translate -projwin {} {} {} {} -a_nodata 0.0 -of GTiff {} {}".format(extend[0], extend[3], extend[2], extend[1], path_raster, path_out)
    os.system(bashCommand)
    
    print("finished grid nr. {}".format(i))
# Out:
# finished grid nr. 0
# finished grid nr. 1
# finished grid nr. 2
# finished grid nr. 3
# finished grid nr. 4
# finished grid nr. 5
# finished grid nr. 6
# finished grid nr. 7
# finished grid nr. 8
# finished grid nr. 9
# finished grid nr. 10
# finished grid nr. 11
# finished grid nr. 12
# finished grid nr. 13
# finished grid nr. 14
# finished grid nr. 15
# finished grid nr. 16
# finished grid nr. 17
# finished grid nr. 18
# finished grid nr. 19
# finished grid nr. 20
# finished grid nr. 21
# finished grid nr. 22
# finished grid nr. 23
# finished grid nr. 24
# finished grid nr. 25
# finished grid nr. 26
# finished grid nr. 27
# finished grid nr. 28
# finished grid nr. 29
# finished grid nr. 30
# finished grid nr. 31
# finished grid nr. 32
# finished grid nr. 33
# finished grid nr. 34
# finished grid nr. 35
# finished grid nr. 36
# finished grid nr. 37
# finished grid nr. 38
# finished grid nr. 39
# finished grid nr. 40
# finished grid nr. 41
# finished grid nr. 42
# finished grid nr. 43
# finished grid nr. 44
# finished grid nr. 45
# finished grid nr. 46
# finished grid nr. 47
# finished grid nr. 48
# finished grid nr. 49
# finished grid nr. 50
# finished grid nr. 51
# finished grid nr. 52
# finished grid nr. 53
# finished grid nr. 54
# finished grid nr. 55
# finished grid nr. 56
# finished grid nr. 57
# finished grid nr. 58
# finished grid nr. 59
# finished grid nr. 60
# finished grid nr. 61
# finished grid nr. 62
# finished grid nr. 63
# finished grid nr. 64
# finished grid nr. 65
# finished grid nr. 66
# finished grid nr. 67
# finished grid nr. 68
# finished grid nr. 69
# finished grid nr. 70
# finished grid nr. 71
# finished grid nr. 72
# finished grid nr. 73
# finished grid nr. 74
# finished grid nr. 75
# finished grid nr. 76
# finished grid nr. 77
# finished grid nr. 78
# finished grid nr. 79
# finished grid nr. 80
# finished grid nr. 81
# finished grid nr. 82
# finished grid nr. 83
# finished grid nr. 84
# finished grid nr. 85
# finished grid nr. 86
# finished grid nr. 87
# finished grid nr. 88
# finished grid nr. 89
# finished grid nr. 90
# finished grid nr. 91
# finished grid nr. 92
# finished grid nr. 93
# finished grid nr. 94
# finished grid nr. 95
# finished grid nr. 96
# finished grid nr. 97
# finished grid nr. 98
# finished grid nr. 99
# finished grid nr. 100
# finished grid nr. 101
# finished grid nr. 102
# finished grid nr. 103
# finished grid nr. 104
# finished grid nr. 105
# finished grid nr. 106
# finished grid nr. 107
# finished grid nr. 108
# finished grid nr. 109
# finished grid nr. 110
# finished grid nr. 111
# finished grid nr. 112
# finished grid nr. 113
# finished grid nr. 114
# finished grid nr. 115
# finished grid nr. 116
# finished grid nr. 117
# finished grid nr. 118
# finished grid nr. 119
# finished grid nr. 120
# finished grid nr. 121
# finished grid nr. 122
# finished grid nr. 123
# finished grid nr. 124
# finished grid nr. 125
# finished grid nr. 126
# finished grid nr. 127
# finished grid nr. 128
# finished grid nr. 129
# finished grid nr. 130
# finished grid nr. 131
# finished grid nr. 132
# finished grid nr. 133
# finished grid nr. 134
# finished grid nr. 135
# finished grid nr. 136
# finished grid nr. 137
# finished grid nr. 138
# finished grid nr. 139
# finished grid nr. 140
# finished grid nr. 141
# finished grid nr. 142
# finished grid nr. 143
# finished grid nr. 144
# finished grid nr. 145
# finished grid nr. 146
# finished grid nr. 147
# finished grid nr. 148
# finished grid nr. 149
# finished grid nr. 150
# finished grid nr. 151
# finished grid nr. 152
# finished grid nr. 153
# finished grid nr. 154
# finished grid nr. 155
# finished grid nr. 156
# finished grid nr. 157
# finished grid nr. 158
# finished grid nr. 159
# finished grid nr. 160
# finished grid nr. 161
# finished grid nr. 162
# finished grid nr. 163
# finished grid nr. 164
# finished grid nr. 165
# finished grid nr. 166
# finished grid nr. 167
# finished grid nr. 168
# finished grid nr. 169
# finished grid nr. 170
# finished grid nr. 171
# finished grid nr. 172
# finished grid nr. 173
# finished grid nr. 174
# finished grid nr. 175
# finished grid nr. 176
# finished grid nr. 177
# finished grid nr. 178
# finished grid nr. 179
# finished grid nr. 180
# finished grid nr. 181
# finished grid nr. 182
# finished grid nr. 183
# finished grid nr. 184
# finished grid nr. 185
# finished grid nr. 186
# finished grid nr. 187
# finished grid nr. 188
# finished grid nr. 189
# finished grid nr. 190
# finished grid nr. 191
# finished grid nr. 192
# finished grid nr. 193
# finished grid nr. 194
# finished grid nr. 195
# finished grid nr. 196
# finished grid nr. 197
# finished grid nr. 198
# finished grid nr. 199
# finished grid nr. 200
# finished grid nr. 201
# finished grid nr. 202
# finished grid nr. 203
# finished grid nr. 204
# finished grid nr. 205
# finished grid nr. 206
# finished grid nr. 207
# finished grid nr. 208
# finished grid nr. 209
# finished grid nr. 210
# finished grid nr. 211
# finished grid nr. 212
# finished grid nr. 213
# finished grid nr. 214
# finished grid nr. 215
# finished grid nr. 216
# finished grid nr. 217
# finished grid nr. 218
# finished grid nr. 219
# finished grid nr. 220
# finished grid nr. 221
# finished grid nr. 222
# finished grid nr. 223
# finished grid nr. 224
# finished grid nr. 225
# finished grid nr. 226
# finished grid nr. 227
# finished grid nr. 228
# finished grid nr. 229
# finished grid nr. 230
# finished grid nr. 231
# finished grid nr. 232
# finished grid nr. 233
# finished grid nr. 234
# finished grid nr. 235
# finished grid nr. 236
# finished grid nr. 237
# finished grid nr. 238
# finished grid nr. 239
# finished grid nr. 240
# finished grid nr. 241
# finished grid nr. 242
# finished grid nr. 243
# finished grid nr. 244
# finished grid nr. 245
# finished grid nr. 246
# finished grid nr. 247
# finished grid nr. 248
# finished grid nr. 249
# finished grid nr. 250
# finished grid nr. 251
# finished grid nr. 252
# finished grid nr. 253
# finished grid nr. 254
# finished grid nr. 255
# finished grid nr. 256
# finished grid nr. 257
# finished grid nr. 258
# finished grid nr. 259
# finished grid nr. 260
# finished grid nr. 261
# finished grid nr. 262
# finished grid nr. 263
# finished grid nr. 264
# finished grid nr. 265
# finished grid nr. 266
# finished grid nr. 267
# finished grid nr. 268
# finished grid nr. 269
# finished grid nr. 270
# finished grid nr. 271
# finished grid nr. 272
# finished grid nr. 273
# finished grid nr. 274
# finished grid nr. 275
# finished grid nr. 276
# finished grid nr. 277
# finished grid nr. 278
# finished grid nr. 279
# finished grid nr. 280
# finished grid nr. 281
# finished grid nr. 282
# finished grid nr. 283
# finished grid nr. 284
# finished grid nr. 285
# finished grid nr. 286
# finished grid nr. 287
# finished grid nr. 288
# finished grid nr. 289
# finished grid nr. 290
# finished grid nr. 291
# finished grid nr. 292
# finished grid nr. 293
# finished grid nr. 294
# finished grid nr. 295
# finished grid nr. 296
# finished grid nr. 297
# finished grid nr. 298
# finished grid nr. 299
# finished grid nr. 300
# finished grid nr. 301
# finished grid nr. 302
# finished grid nr. 303
# finished grid nr. 304
# finished grid nr. 305
# finished grid nr. 306
# finished grid nr. 307
# finished grid nr. 308
# finished grid nr. 309
# finished grid nr. 310
# finished grid nr. 311
# finished grid nr. 312
# finished grid nr. 313
# finished grid nr. 314
# finished grid nr. 315
# finished grid nr. 316
# finished grid nr. 317
# finished grid nr. 318
# finished grid nr. 319
# finished grid nr. 320
# finished grid nr. 321
# finished grid nr. 322
# finished grid nr. 323
# finished grid nr. 324
# finished grid nr. 325
# finished grid nr. 326
# finished grid nr. 327
# finished grid nr. 328
# finished grid nr. 329
# finished grid nr. 330
# finished grid nr. 331
# finished grid nr. 332
# finished grid nr. 333
# finished grid nr. 334
# finished grid nr. 335
# finished grid nr. 336
# finished grid nr. 337
# finished grid nr. 338
# finished grid nr. 339
# finished grid nr. 340
# finished grid nr. 341
# finished grid nr. 342
# finished grid nr. 343
# finished grid nr. 344
# finished grid nr. 345
# finished grid nr. 346
# finished grid nr. 347
# finished grid nr. 348
# finished grid nr. 349
# finished grid nr. 350
# finished grid nr. 351
# finished grid nr. 352
# finished grid nr. 353
# finished grid nr. 354
# finished grid nr. 355
# finished grid nr. 356
# finished grid nr. 357
# finished grid nr. 358
# finished grid nr. 359
# finished grid nr. 360
