# %%
import geopandas as gpd
import pandas as pd
from osgeo import gdal
import sys
import os
import numpy as np

from shapely.geometry import Polygon
from pyproj import CRS

# %%
left = 595450.197129
top = 514827.375566
right = 672082.197129
bottom = 469919.375566

# width = pixels * resolution
#width = 512 * 0.2
width = 103

# %%
np.arange(left, right, width)
# Out:
# array([595450.197129, 595553.197129, 595656.197129, 595759.197129,
#        595862.197129, 595965.197129, 596068.197129, 596171.197129,
#        596274.197129, 596377.197129, 596480.197129, 596583.197129,
#        596686.197129, 596789.197129, 596892.197129, 596995.197129,
#        597098.197129, 597201.197129, 597304.197129, 597407.197129,
#        597510.197129, 597613.197129, 597716.197129, 597819.197129,
#        597922.197129, 598025.197129, 598128.197129, 598231.197129,
#        598334.197129, 598437.197129, 598540.197129, 598643.197129,
#        598746.197129, 598849.197129, 598952.197129, 599055.197129,
#        599158.197129, 599261.197129, 599364.197129, 599467.197129,
#        599570.197129, 599673.197129, 599776.197129, 599879.197129,
#        599982.197129, 600085.197129, 600188.197129, 600291.197129,
#        600394.197129, 600497.197129, 600600.197129, 600703.197129,
#        600806.197129, 600909.197129, 601012.197129, 601115.197129,
# ...

# %%
np.arange(top, bottom, -width)
# Out:
# array([514827.375566, 514724.375566, 514621.375566, 514518.375566,
#        514415.375566, 514312.375566, 514209.375566, 514106.375566,
#        514003.375566, 513900.375566, 513797.375566, 513694.375566,
#        513591.375566, 513488.375566, 513385.375566, 513282.375566,
#        513179.375566, 513076.375566, 512973.375566, 512870.375566,
#        512767.375566, 512664.375566, 512561.375566, 512458.375566,
#        512355.375566, 512252.375566, 512149.375566, 512046.375566,
#        511943.375566, 511840.375566, 511737.375566, 511634.375566,
#        511531.375566, 511428.375566, 511325.375566, 511222.375566,
#        511119.375566, 511016.375566, 510913.375566, 510810.375566,
#        510707.375566, 510604.375566, 510501.375566, 510398.375566,
#        510295.375566, 510192.375566, 510089.375566, 509986.375566,
#        509883.375566, 509780.375566, 509677.375566, 509574.375566,
#        509471.375566, 509368.375566, 509265.375566, 509162.375566,
# ...

# %%
polys = []

for col in np.arange(left, left+(4*103), width):
    for row in np.arange(top, top-(3*103), -width):
        print(col, row)
        polys.append(Polygon ([(col, row), (col+width, row), (col+width, row-width), (col, row-width), (col, row)]))
# Out:
# 595759.197129 514621.375566
# 595759.197129 514621.375566
# 595759.197129 514621.375566
# 595759.197129 514621.375566
# 595759.197129 514621.375566
# 595759.197129 514621.375566
# 595759.197129 514621.375566
# 595759.197129 514621.375566
# 595759.197129 514621.375566
# 595759.197129 514621.375566
# 595759.197129 514621.375566
# 595759.197129 514621.375566

# %%
len(polys)
# Out:
# 12

# %%
crs = CRS.from_user_input('PROJCS["Austria_Lambert",GEOGCS["GCS_BESSEL_AUT",DATUM["D_BESSEL_AUT",SPHEROID["Bessel_1841",6377397.155,299.1528128,AUTHORITY["EPSG","7004"]]],PRIMEM["Greenwich",0],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]]],PROJECTION["Lambert_Conformal_Conic_2SP"],PARAMETER["latitude_of_origin",47.5],PARAMETER["central_meridian",13.333333333],PARAMETER["standard_parallel_1",46],PARAMETER["standard_parallel_2",49],PARAMETER["false_easting",400000],PARAMETER["false_northing",400000],UNIT["metre",1,AUTHORITY["EPSG","9001"]],AXIS["Easting",EAST],AXIS["Northing",NORTH]]')

# %%
d = {'id': range(len(polys)), 'geometry': polys}
gdf = gpd.GeoDataFrame(d, crs=crs)

# %%
gdf
# Out:
#     id                                           geometry
# 0    0  POLYGON ((595450.197 514827.376, 595553.197 51...
# 1    1  POLYGON ((595450.197 514724.376, 595553.197 51...
# 2    2  POLYGON ((595450.197 514621.376, 595553.197 51...
# 3    3  POLYGON ((595553.197 514827.376, 595656.197 51...
# 4    4  POLYGON ((595553.197 514724.376, 595656.197 51...
# 5    5  POLYGON ((595553.197 514621.376, 595656.197 51...
# 6    6  POLYGON ((595656.197 514827.376, 595759.197 51...
# 7    7  POLYGON ((595656.197 514724.376, 595759.197 51...
# 8    8  POLYGON ((595656.197 514621.376, 595759.197 51...
# 9    9  POLYGON ((595759.197 514827.376, 595862.197 51...
# 10  10  POLYGON ((595759.197 514724.376, 595862.197 51...
# 11  11  POLYGON ((595759.197 514621.376, 595862.197 51...

# %%
gdf.to_file("/home/philipp/Data/edin_diss/grid/grid_test.shp")

# %%
gdf.area
# Out:
# 0     10609.0
# 1     10609.0
# 2     10609.0
# 3     10609.0
# 4     10609.0
# 5     10609.0
# 6     10609.0
# 7     10609.0
# 8     10609.0
# 9     10609.0
# 10    10609.0
# 11    10609.0
# dtype: float64
